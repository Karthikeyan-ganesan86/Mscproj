# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthikeyan-ganesan86/Mscproj/blob/main/08_DISSERT_RL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## REINFORCEMENT LEARNING IN TRADING
#
# #### 5 Agents(Methods) used were
# ###### A2C Advantage Actor Critic
# ###### DDPG Deep Deterministic Policy Gradient
# ###### PPO Proximal Policy Optimization
# ###### TD3 Twin Delayed DDPG
# ###### SAC Soft Actor-Critic

# %% [markdown]
# Packages installed

# %%
import pandas as pd
import numpy as np
import datetime
import yfinance as yf

from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl import config_tickers
from finrl.config import INDICATORS

import itertools

# %% [markdown]
# FETCH DATA Data downloaded are in the form of OHLCV, corresponding to open, high, low, close, volume

# %% [markdown]
# **Using yfinance**

# %%
aapl_df_yf = yf.download(tickers = "aapl", start='2020-01-01', end='2020-01-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# FinRL fpr downloading data

# %%
aapl_df_finrl = YahooDownloader(start_date = '2020-01-01',
                                end_date = '2020-01-31',
                                ticker_list = ['aapl']).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (20, 8)

# %%
config_tickers.DOW_30_TICKER
# Out:
# ['AXP',
#  'AMGN',
#  'AAPL',
#  'BA',
#  'CAT',
#  'CSCO',
#  'CVX',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'KO',
#  'JPM',
#  'MCD',
#  'MMM',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'TRV',
#  'UNH',
#  'CRM',
#  'VZ',
#  'V',
#  'WBA',
#  'WMT',
#  'DIS',
#  'DOW']

# %%
TRAIN_START_DATE = '2009-01-01'
TRAIN_END_DATE = '2020-07-01'
TRADE_START_DATE = '2020-07-01'
TRADE_END_DATE = '2021-10-29'

# %%
df_raw = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (94301, 8)

# %% [markdown]
# ##Preprocessing the data finding missing data and converting data into features

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_vix=True,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df_raw)
# Out:
# Successfully added technical indicators
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (3228, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.head()
# Out:
#          date   tic       open       high        low      close       volume  \
# 0  2009-01-02  AAPL   3.067143   3.251429   3.041429   2.747391  746015200.0
# 1  2009-01-02  AMGN  58.590000  59.080002  57.750000  42.737888    6547900.0
# 2  2009-01-02   AXP  18.570000  19.520000  18.400000  15.193851   10955700.0
# 3  2009-01-02    BA  42.799999  45.560001  42.779999  33.941101    7010200.0
# 4  2009-01-02   CAT  44.910000  46.980000  44.709999  31.093393    7117200.0
#
#    day  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  4.0   0.0  2.969344  2.641387   100.0  66.666667  100.0      2.747391
# 1  4.0   0.0  2.969344  2.641387   100.0  66.666667  100.0     42.737888
# 2  4.0   0.0  2.969344  2.641387   100.0  66.666667  100.0     15.193851
# 3  4.0   0.0  2.969344  2.641387   100.0  66.666667  100.0     33.941101
# 4  4.0   0.0  2.969344  2.641387   100.0  66.666667  100.0     31.093393
#
#    close_60_sma        vix  turbulence
# 0      2.747391  39.189999         0.0
# 1     42.737888  39.189999         0.0
# 2     15.193851  39.189999         0.0
# 3     33.941101  39.189999         0.0
# 4     31.093393  39.189999         0.0

# %%
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 83897
# 9715

# %%
train.to_csv('train_data.csv')
trade.to_csv('trade_data.csv')

# %%
import pandas as pd
from stable_baselines3.common.logger import configure

from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.config import INDICATORS, TRAINED_MODEL_DIR, RESULTS_DIR
from finrl.main import check_and_make_directories
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv

check_and_make_directories([TRAINED_MODEL_DIR])

# %%
train = pd.read_csv('train_data.csv')

# If you are not using the data generated from part 1 of this tutorial, make sure
# it has the columns and index in the form that could be make into the environment.
# Then you can comment and skip the following two lines.
train = train.set_index(train.columns[0])
train.index.names = ['']

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# ##Train Reinforcement Learning Agents

# %% [markdown]
# Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)

# Set the corresponding values to 'True' for the algorithms that you want to use
if_using_a2c = True
if_using_ddpg = True
if_using_ppo = True
if_using_td3 = True
if_using_sac = True

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device
# Logging to results/a2c

# %%
trained_a2c = agent.train_model(model=model_a2c,
                             tb_log_name='a2c',
                             total_timesteps=50000) if if_using_a2c else None
# Out:
# -------------------------------------
# | time/                 |           |
# |    fps                | 82        |
# |    iterations         | 100       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 7.49      |
# |    reward             | 0.7632069 |
# |    std                | 1         |
# |    value_loss         | 0.409     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 68         |
# |    iterations         | 200        |
# |    time_elapsed       | 14         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.155      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -7.03      |
# |    reward             | -1.3922539 |
# |    std                | 1          |
# |    value_loss         | 0.255      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 300       |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -161      |
# |    reward             | 3.4390717 |
# |    std                | 1         |
# |    value_loss         | 15.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 76        |
# |    iterations         | 400       |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -11.2     |
# |    reward             | 4.6192064 |
# |    std                | 1         |
# |    value_loss         | 1.48      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 75         |
# |    iterations         | 500        |
# |    time_elapsed       | 33         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0.0169     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 391        |
# |    reward             | -3.6484845 |
# |    std                | 1          |
# |    value_loss         | 107        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 71          |
# |    iterations         | 600         |
# |    time_elapsed       | 41          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | -2.38e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | 113         |
# |    reward             | -0.11071551 |
# |    std                | 1.01        |
# |    value_loss         | 9.26        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 74        |
# |    iterations         | 700       |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -41.3     |
# |    reward             | -1.826982 |
# |    std                | 1.01      |
# |    value_loss         | 1.08      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 77         |
# |    iterations         | 800        |
# |    time_elapsed       | 51         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 92.7       |
# |    reward             | -2.9243767 |
# |    std                | 1.01       |
# |    value_loss         | 4.75       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 74        |
# |    iterations         | 900       |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 248       |
# |    reward             | -2.314666 |
# |    std                | 1.01      |
# |    value_loss         | 33.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 73        |
# |    iterations         | 1000      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -68.6     |
# |    reward             | -7.425001 |
# |    std                | 1.01      |
# |    value_loss         | 2.71      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 74        |
# |    iterations         | 1100      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -260      |
# |    reward             | 1.1285796 |
# |    std                | 1.01      |
# |    value_loss         | 44        |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 73         |
# |    iterations         | 1200       |
# |    time_elapsed       | 81         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -97.5      |
# |    reward             | 0.07546405 |
# |    std                | 1.01       |
# |    value_loss         | 7.23       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 1300       |
# |    time_elapsed       | 90         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 93.5       |
# |    reward             | -4.1323624 |
# |    std                | 1.01       |
# |    value_loss         | 16.9       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 1400      |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 171       |
# |    reward             | 1.1899927 |
# |    std                | 1.01      |
# |    value_loss         | 23.1      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 73        |
# |    iterations         | 1500      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 175       |
# |    reward             | 1.7222489 |
# |    std                | 1         |
# |    value_loss         | 19.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 73        |
# |    iterations         | 1600      |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 293       |
# |    reward             | 1.0108727 |
# |    std                | 1.01      |
# |    value_loss         | 50.3      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 1700      |
# |    time_elapsed       | 117       |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -216      |
# |    reward             | 6.5018816 |
# |    std                | 1.01      |
# |    value_loss         | 33.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 73        |
# |    iterations         | 1800      |
# |    time_elapsed       | 122       |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0.102     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -8.11     |
# |    reward             | 1.2320672 |
# |    std                | 1.01      |
# |    value_loss         | 0.896     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 74          |
# |    iterations         | 1900        |
# |    time_elapsed       | 127         |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | -28.3       |
# |    reward             | -0.17734917 |
# |    std                | 1.01        |
# |    value_loss         | 2.79        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 73         |
# |    iterations         | 2000       |
# |    time_elapsed       | 136        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 72         |
# |    reward             | -0.2663279 |
# |    std                | 1.01       |
# |    value_loss         | 6.16       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 72       |
# |    iterations         | 2100     |
# |    time_elapsed       | 145      |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -41.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 97.5     |
# |    reward             | 0.700051 |
# |    std                | 1.01     |
# |    value_loss         | 7.85     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 2200      |
# |    time_elapsed       | 154       |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | 64.3      |
# |    reward             | -6.369167 |
# |    std                | 1.01      |
# |    value_loss         | 12.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 70        |
# |    iterations         | 2300      |
# |    time_elapsed       | 163       |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | -2.26e+03 |
# |    reward             | -9.422175 |
# |    std                | 1.01      |
# |    value_loss         | 3.47e+03  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 70        |
# |    iterations         | 2400      |
# |    time_elapsed       | 169       |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | 112       |
# |    reward             | 1.1492624 |
# |    std                | 1.01      |
# |    value_loss         | 12.9      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 2500      |
# |    time_elapsed       | 175       |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -73       |
# |    reward             | 1.0883809 |
# |    std                | 1.01      |
# |    value_loss         | 3.23      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 2600      |
# |    time_elapsed       | 181       |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -42.6     |
# |    reward             | 2.2127857 |
# |    std                | 1.02      |
# |    value_loss         | 1.31      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 70         |
# |    iterations         | 2700       |
# |    time_elapsed       | 190        |
# |    total_timesteps    | 13500      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2699       |
# |    policy_loss        | 0.031      |
# |    reward             | -1.5338311 |
# |    std                | 1.01       |
# |    value_loss         | 1.04       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 2800      |
# |    time_elapsed       | 195       |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 455       |
# |    reward             | 2.4976218 |
# |    std                | 1.01      |
# |    value_loss         | 148       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 2900      |
# |    time_elapsed       | 200       |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -78.5     |
# |    reward             | 1.1421851 |
# |    std                | 1.01      |
# |    value_loss         | 3.7       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 3000      |
# |    time_elapsed       | 208       |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0.00475   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | 6.64      |
# |    reward             | 0.2533748 |
# |    std                | 1.01      |
# |    value_loss         | 0.596     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 71         |
# |    iterations         | 3100       |
# |    time_elapsed       | 217        |
# |    total_timesteps    | 15500      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3099       |
# |    policy_loss        | 19.6       |
# |    reward             | -0.7971381 |
# |    std                | 1.02       |
# |    value_loss         | 0.5        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 3200       |
# |    time_elapsed       | 222        |
# |    total_timesteps    | 16000      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3199       |
# |    policy_loss        | -118       |
# |    reward             | -0.1313023 |
# |    std                | 1.02       |
# |    value_loss         | 22.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 3300       |
# |    time_elapsed       | 227        |
# |    total_timesteps    | 16500      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3299       |
# |    policy_loss        | 123        |
# |    reward             | -2.0830514 |
# |    std                | 1.02       |
# |    value_loss         | 15.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 3400      |
# |    time_elapsed       | 236       |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -3.53     |
# |    reward             | 22.797813 |
# |    std                | 1.02      |
# |    value_loss         | 40.4      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 71          |
# |    iterations         | 3500        |
# |    time_elapsed       | 243         |
# |    total_timesteps    | 17500       |
# | train/                |             |
# |    entropy_loss       | -41.6       |
# |    explained_variance | 0.0916      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3499        |
# |    policy_loss        | 209         |
# |    reward             | 0.059161413 |
# |    std                | 1.02        |
# |    value_loss         | 28.4        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 3600      |
# |    time_elapsed       | 248       |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -205      |
# |    reward             | 1.9171958 |
# |    std                | 1.02      |
# |    value_loss         | 36.3      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 72       |
# |    iterations         | 3700     |
# |    time_elapsed       | 256      |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -41.7    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 278      |
# |    reward             | 4.892124 |
# |    std                | 1.02     |
# |    value_loss         | 49.6     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 3800      |
# |    time_elapsed       | 265       |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | 279       |
# |    reward             | 2.6234467 |
# |    std                | 1.02      |
# |    value_loss         | 45.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 3900      |
# |    time_elapsed       | 270       |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -196      |
# |    reward             | 2.2023823 |
# |    std                | 1.02      |
# |    value_loss         | 30.2      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 4000      |
# |    time_elapsed       | 275       |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | -0.00307  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | 335       |
# |    reward             | 0.5464546 |
# |    std                | 1.02      |
# |    value_loss         | 109       |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 72          |
# |    iterations         | 4100        |
# |    time_elapsed       | 283         |
# |    total_timesteps    | 20500       |
# | train/                |             |
# |    entropy_loss       | -41.7       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4099        |
# |    policy_loss        | -58.5       |
# |    reward             | 0.017647186 |
# |    std                | 1.02        |
# |    value_loss         | 5.5         |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 72       |
# |    iterations         | 4200     |
# |    time_elapsed       | 291      |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -41.8    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -240     |
# |    reward             | 1.962561 |
# |    std                | 1.02     |
# |    value_loss         | 42.3     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 4300       |
# |    time_elapsed       | 296        |
# |    total_timesteps    | 21500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0.33       |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4299       |
# |    policy_loss        | -92.3      |
# |    reward             | 0.82983434 |
# |    std                | 1.02       |
# |    value_loss         | 12.6       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 4400       |
# |    time_elapsed       | 302        |
# |    total_timesteps    | 22000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4399       |
# |    policy_loss        | 157        |
# |    reward             | -2.7135816 |
# |    std                | 1.02       |
# |    value_loss         | 22.9       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 72       |
# |    iterations         | 4500     |
# |    time_elapsed       | 311      |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -41.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 1.04e+03 |
# |    reward             | 8.377399 |
# |    std                | 1.02     |
# |    value_loss         | 639      |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 71         |
# |    iterations         | 4600       |
# |    time_elapsed       | 320        |
# |    total_timesteps    | 23000      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4599       |
# |    policy_loss        | 368        |
# |    reward             | -5.3708115 |
# |    std                | 1.02       |
# |    value_loss         | 141        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 4700       |
# |    time_elapsed       | 325        |
# |    total_timesteps    | 23500      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4699       |
# |    policy_loss        | -69.4      |
# |    reward             | 0.07737858 |
# |    std                | 1.02       |
# |    value_loss         | 9.96       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 4800       |
# |    time_elapsed       | 333        |
# |    total_timesteps    | 24000      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4799       |
# |    policy_loss        | -332       |
# |    reward             | -3.1431804 |
# |    std                | 1.02       |
# |    value_loss         | 81.2       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 4900      |
# |    time_elapsed       | 341       |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -90.7     |
# |    reward             | 1.6347458 |
# |    std                | 1.02      |
# |    value_loss         | 8.78      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 5000       |
# |    time_elapsed       | 346        |
# |    total_timesteps    | 25000      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4999       |
# |    policy_loss        | 61.1       |
# |    reward             | -2.2814157 |
# |    std                | 1.02       |
# |    value_loss         | 5.14       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 5100      |
# |    time_elapsed       | 351       |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | 572       |
# |    reward             | 1.1365272 |
# |    std                | 1.02      |
# |    value_loss         | 206       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 5200      |
# |    time_elapsed       | 360       |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0.00087   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -637      |
# |    reward             | 12.495003 |
# |    std                | 1.02      |
# |    value_loss         | 238       |
# -------------------------------------
# day: 2892, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5414203.07
# total_reward: 4414203.07
# total_cost: 16724.51
# total_trades: 45045
# Sharpe: 0.780
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 5300      |
# |    time_elapsed       | 367       |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -70.3     |
# |    reward             | 0.3864288 |
# |    std                | 1.02      |
# |    value_loss         | 2.96      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 5400       |
# |    time_elapsed       | 372        |
# |    total_timesteps    | 27000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5399       |
# |    policy_loss        | 61.2       |
# |    reward             | 0.35613534 |
# |    std                | 1.02       |
# |    value_loss         | 18.5       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 5500      |
# |    time_elapsed       | 378       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | 129       |
# |    reward             | 1.5158627 |
# |    std                | 1.02      |
# |    value_loss         | 19.7      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 72           |
# |    iterations         | 5600         |
# |    time_elapsed       | 387          |
# |    total_timesteps    | 28000        |
# | train/                |              |
# |    entropy_loss       | -41.7        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 5599         |
# |    policy_loss        | -159         |
# |    reward             | -0.011531715 |
# |    std                | 1.02         |
# |    value_loss         | 18.5         |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 72          |
# |    iterations         | 5700        |
# |    time_elapsed       | 393         |
# |    total_timesteps    | 28500       |
# | train/                |             |
# |    entropy_loss       | -41.7       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5699        |
# |    policy_loss        | -117        |
# |    reward             | -0.15264852 |
# |    std                | 1.02        |
# |    value_loss         | 19.3        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 72       |
# |    iterations         | 5800     |
# |    time_elapsed       | 398      |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -41.8    |
# |    explained_variance | -1.86    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -17.9    |
# |    reward             | 1.338325 |
# |    std                | 1.02     |
# |    value_loss         | 10.4     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 5900       |
# |    time_elapsed       | 405        |
# |    total_timesteps    | 29500      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5899       |
# |    policy_loss        | 15.5       |
# |    reward             | -1.0033805 |
# |    std                | 1.02       |
# |    value_loss         | 0.844      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 6000       |
# |    time_elapsed       | 414        |
# |    total_timesteps    | 30000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5999       |
# |    policy_loss        | 61.4       |
# |    reward             | -1.3214865 |
# |    std                | 1.02       |
# |    value_loss         | 4.68       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 6100       |
# |    time_elapsed       | 419        |
# |    total_timesteps    | 30500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6099       |
# |    policy_loss        | -49.3      |
# |    reward             | -2.4757805 |
# |    std                | 1.02       |
# |    value_loss         | 6.76       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 73          |
# |    iterations         | 6200        |
# |    time_elapsed       | 424         |
# |    total_timesteps    | 31000       |
# | train/                |             |
# |    entropy_loss       | -41.8       |
# |    explained_variance | -0.0112     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6199        |
# |    policy_loss        | 39.5        |
# |    reward             | 0.045396205 |
# |    std                | 1.02        |
# |    value_loss         | 1.91        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 72       |
# |    iterations         | 6300     |
# |    time_elapsed       | 432      |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -41.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 165      |
# |    reward             | 4.346759 |
# |    std                | 1.02     |
# |    value_loss         | 25.9     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 6400      |
# |    time_elapsed       | 440       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | 173       |
# |    reward             | 1.8438588 |
# |    std                | 1.02      |
# |    value_loss         | 16.6      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 72       |
# |    iterations         | 6500     |
# |    time_elapsed       | 445      |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -41.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | 44       |
# |    reward             | -5.43288 |
# |    std                | 1.02     |
# |    value_loss         | 14.3     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 6600       |
# |    time_elapsed       | 452        |
# |    total_timesteps    | 33000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0.000391   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6599       |
# |    policy_loss        | -101       |
# |    reward             | 0.12364809 |
# |    std                | 1.02       |
# |    value_loss         | 11.8       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 6700       |
# |    time_elapsed       | 460        |
# |    total_timesteps    | 33500      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 0.000168   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6699       |
# |    policy_loss        | -780       |
# |    reward             | -7.2032905 |
# |    std                | 1.02       |
# |    value_loss         | 421        |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 72           |
# |    iterations         | 6800         |
# |    time_elapsed       | 469          |
# |    total_timesteps    | 34000        |
# | train/                |              |
# |    entropy_loss       | -41.8        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 6799         |
# |    policy_loss        | -311         |
# |    reward             | -0.008058804 |
# |    std                | 1.02         |
# |    value_loss         | 59.8         |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 6900       |
# |    time_elapsed       | 479        |
# |    total_timesteps    | 34500      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6899       |
# |    policy_loss        | -406       |
# |    reward             | 0.26217896 |
# |    std                | 1.02       |
# |    value_loss         | 127        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 71         |
# |    iterations         | 7000       |
# |    time_elapsed       | 487        |
# |    total_timesteps    | 35000      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6999       |
# |    policy_loss        | 122        |
# |    reward             | 0.04650138 |
# |    std                | 1.03       |
# |    value_loss         | 8.78       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 71        |
# |    iterations         | 7100      |
# |    time_elapsed       | 493       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | 17.2      |
# |    reward             | 1.4370891 |
# |    std                | 1.03      |
# |    value_loss         | 0.864     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 7200      |
# |    time_elapsed       | 498       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | -0.00137  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -266      |
# |    reward             | 1.3912901 |
# |    std                | 1.03      |
# |    value_loss         | 45        |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 7300       |
# |    time_elapsed       | 506        |
# |    total_timesteps    | 36500      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7299       |
# |    policy_loss        | 371        |
# |    reward             | -2.2000074 |
# |    std                | 1.03       |
# |    value_loss         | 102        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 71         |
# |    iterations         | 7400       |
# |    time_elapsed       | 514        |
# |    total_timesteps    | 37000      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7399       |
# |    policy_loss        | -482       |
# |    reward             | -2.8538966 |
# |    std                | 1.03       |
# |    value_loss         | 149        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 7500       |
# |    time_elapsed       | 519        |
# |    total_timesteps    | 37500      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7499       |
# |    policy_loss        | 342        |
# |    reward             | -2.2600892 |
# |    std                | 1.03       |
# |    value_loss         | 84.8       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 7600      |
# |    time_elapsed       | 527       |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7599      |
# |    policy_loss        | -161      |
# |    reward             | 2.2704742 |
# |    std                | 1.03      |
# |    value_loss         | 14.6      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 71         |
# |    iterations         | 7700       |
# |    time_elapsed       | 535        |
# |    total_timesteps    | 38500      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7699       |
# |    policy_loss        | -82.1      |
# |    reward             | 0.99572796 |
# |    std                | 1.03       |
# |    value_loss         | 5.25       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 71         |
# |    iterations         | 7800       |
# |    time_elapsed       | 542        |
# |    total_timesteps    | 39000      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7799       |
# |    policy_loss        | -48.6      |
# |    reward             | -3.6607978 |
# |    std                | 1.03       |
# |    value_loss         | 2.43       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 7900      |
# |    time_elapsed       | 547       |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0.000544  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | 395       |
# |    reward             | 4.0169497 |
# |    std                | 1.03      |
# |    value_loss         | 116       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 8000      |
# |    time_elapsed       | 554       |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7999      |
# |    policy_loss        | -186      |
# |    reward             | 0.5888808 |
# |    std                | 1.03      |
# |    value_loss         | 28.6      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 71       |
# |    iterations         | 8100     |
# |    time_elapsed       | 563      |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -41.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | 20.8     |
# |    reward             | 5.407161 |
# |    std                | 1.03     |
# |    value_loss         | 16.8     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 72          |
# |    iterations         | 8200        |
# |    time_elapsed       | 568         |
# |    total_timesteps    | 41000       |
# | train/                |             |
# |    entropy_loss       | -41.9       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8199        |
# |    policy_loss        | 5.33        |
# |    reward             | -0.05689559 |
# |    std                | 1.03        |
# |    value_loss         | 0.0609      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 8300       |
# |    time_elapsed       | 573        |
# |    total_timesteps    | 41500      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | -0.042     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8299       |
# |    policy_loss        | 46.4       |
# |    reward             | -0.8695793 |
# |    std                | 1.03       |
# |    value_loss         | 2.73       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 8400       |
# |    time_elapsed       | 582        |
# |    total_timesteps    | 42000      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8399       |
# |    policy_loss        | -58.2      |
# |    reward             | -1.0425047 |
# |    std                | 1.03       |
# |    value_loss         | 2.61       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 8500       |
# |    time_elapsed       | 590        |
# |    total_timesteps    | 42500      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8499       |
# |    policy_loss        | -138       |
# |    reward             | -0.2940351 |
# |    std                | 1.03       |
# |    value_loss         | 14.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 8600       |
# |    time_elapsed       | 595        |
# |    total_timesteps    | 43000      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8599       |
# |    policy_loss        | 10.5       |
# |    reward             | -13.346794 |
# |    std                | 1.03       |
# |    value_loss         | 35.9       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 8700      |
# |    time_elapsed       | 602       |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 0.00248   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | -22.6     |
# |    reward             | 1.3616853 |
# |    std                | 1.03      |
# |    value_loss         | 1.69      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 72       |
# |    iterations         | 8800     |
# |    time_elapsed       | 610      |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -42      |
# |    explained_variance | 0.00419  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8799     |
# |    policy_loss        | -95.7    |
# |    reward             | 2.20646  |
# |    std                | 1.03     |
# |    value_loss         | 5.31     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 72          |
# |    iterations         | 8900        |
# |    time_elapsed       | 616         |
# |    total_timesteps    | 44500       |
# | train/                |             |
# |    entropy_loss       | -42.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8899        |
# |    policy_loss        | 220         |
# |    reward             | -0.41636208 |
# |    std                | 1.03        |
# |    value_loss         | 27.5        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 9000       |
# |    time_elapsed       | 621        |
# |    total_timesteps    | 45000      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8999       |
# |    policy_loss        | 59.6       |
# |    reward             | -1.2516134 |
# |    std                | 1.04       |
# |    value_loss         | 14.6       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 72       |
# |    iterations         | 9100     |
# |    time_elapsed       | 629      |
# |    total_timesteps    | 45500    |
# | train/                |          |
# |    entropy_loss       | -42.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9099     |
# |    policy_loss        | 52.5     |
# |    reward             | 6.291088 |
# |    std                | 1.04     |
# |    value_loss         | 2.07     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 9200      |
# |    time_elapsed       | 638       |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9199      |
# |    policy_loss        | 14.6      |
# |    reward             | 1.4014382 |
# |    std                | 1.04      |
# |    value_loss         | 2.14      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 9300      |
# |    time_elapsed       | 644       |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9299      |
# |    policy_loss        | -167      |
# |    reward             | 0.8848447 |
# |    std                | 1.04      |
# |    value_loss         | 20.8      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 9400      |
# |    time_elapsed       | 649       |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | 5.36e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9399      |
# |    policy_loss        | 81.4      |
# |    reward             | 0.7819599 |
# |    std                | 1.04      |
# |    value_loss         | 7.04      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 9500      |
# |    time_elapsed       | 658       |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9499      |
# |    policy_loss        | 169       |
# |    reward             | 2.3028324 |
# |    std                | 1.04      |
# |    value_loss         | 25.6      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 9600      |
# |    time_elapsed       | 665       |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9599      |
# |    policy_loss        | -256      |
# |    reward             | 1.5589647 |
# |    std                | 1.04      |
# |    value_loss         | 38.8      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 72          |
# |    iterations         | 9700        |
# |    time_elapsed       | 670         |
# |    total_timesteps    | 48500       |
# | train/                |             |
# |    entropy_loss       | -42.2       |
# |    explained_variance | -0.00266    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9699        |
# |    policy_loss        | 110         |
# |    reward             | -0.71888137 |
# |    std                | 1.04        |
# |    value_loss         | 14          |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 72        |
# |    iterations         | 9800      |
# |    time_elapsed       | 676       |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9799      |
# |    policy_loss        | 384       |
# |    reward             | 10.557784 |
# |    std                | 1.04      |
# |    value_loss         | 88.2      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 9900       |
# |    time_elapsed       | 685        |
# |    total_timesteps    | 49500      |
# | train/                |            |
# |    entropy_loss       | -42.2      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9899       |
# |    policy_loss        | 18.5       |
# |    reward             | 0.59970206 |
# |    std                | 1.04       |
# |    value_loss         | 0.616      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 72         |
# |    iterations         | 10000      |
# |    time_elapsed       | 692        |
# |    total_timesteps    | 50000      |
# | train/                |            |
# |    entropy_loss       | -42.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9999       |
# |    policy_loss        | -19.7      |
# |    reward             | -1.1118525 |
# |    std                | 1.04       |
# |    value_loss         | 2.74       |
# --------------------------------------

# %%
trained_a2c.save(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None

# %% [markdown]
# Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device
# Logging to results/ddpg

# %%
trained_ddpg = agent.train_model(model=model_ddpg,
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None
# Out:
# day: 2892, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 7042738.11
# total_reward: 6042738.11
# total_cost: 6286.05
# total_trades: 33329
# Sharpe: 1.020
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 27        |
# |    time_elapsed    | 426       |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | -46.3     |
# |    critic_loss     | 244       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8679      |
# |    reward          | 2.7918286 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 24        |
# |    time_elapsed    | 960       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | -28.7     |
# |    critic_loss     | 11.2      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20251     |
# |    reward          | 2.7918286 |
# ----------------------------------
# day: 2892, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 4227235.18
# total_reward: 3227235.18
# total_cost: 1036.96
# total_trades: 37648
# Sharpe: 0.757
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 23        |
# |    time_elapsed    | 1507      |
# |    total_timesteps | 34716     |
# | train/             |           |
# |    actor_loss      | -20.5     |
# |    critic_loss     | 6.18      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31823     |
# |    reward          | 2.7918286 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 22        |
# |    time_elapsed    | 2068      |
# |    total_timesteps | 46288     |
# | train/             |           |
# |    actor_loss      | -15.9     |
# |    critic_loss     | 4.97      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 43395     |
# |    reward          | 2.7918286 |
# ----------------------------------

# %%
trained_ddpg.save(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None

# %% [markdown]
# Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to results/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo,
                             tb_log_name='ppo',
                             total_timesteps=200000) if if_using_ppo else None
# Out:
# -----------------------------------
# | time/              |            |
# |    fps             | 78         |
# |    iterations      | 1          |
# |    time_elapsed    | 25         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.98613566 |
# -----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 2            |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0145374425 |
# |    clip_fraction        | 0.2          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.2        |
# |    explained_variance   | 0.00283      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.61         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0237      |
# |    reward               | 0.8325981    |
# |    std                  | 1            |
# |    value_loss           | 11.9         |
# ------------------------------------------
# day: 2892, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 4208548.73
# total_reward: 3208548.73
# total_cost: 339359.49
# total_trades: 81042
# Sharpe: 0.824
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 3           |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014328495 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00999    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0218     |
# |    reward               | -1.2375733  |
# |    std                  | 1           |
# |    value_loss           | 57.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 4           |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015087614 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.000184   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 25.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.016      |
# |    reward               | 2.2403226   |
# |    std                  | 1           |
# |    value_loss           | 73.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 5           |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019997472 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.016       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.5        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0215     |
# |    reward               | 3.7498689   |
# |    std                  | 1.01        |
# |    value_loss           | 19.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 6           |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.017972555 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.0239     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0198     |
# |    reward               | 2.1433022   |
# |    std                  | 1.01        |
# |    value_loss           | 50.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 7           |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.017968506 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | 0.0052      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 30.7        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0189     |
# |    reward               | 0.7266987   |
# |    std                  | 1.01        |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 8           |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.020483641 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.0157     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.1        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0162     |
# |    reward               | 0.5305879   |
# |    std                  | 1.01        |
# |    value_loss           | 31.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 9           |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.016627196 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.0175     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.48        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0241     |
# |    reward               | 1.0695928   |
# |    std                  | 1.01        |
# |    value_loss           | 63.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 10          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.025534377 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | -0.00576    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 74.2        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0131     |
# |    reward               | 0.64027387  |
# |    std                  | 1.01        |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 11          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.022699676 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | -0.00305    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.3        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0178     |
# |    reward               | 1.1873053   |
# |    std                  | 1.02        |
# |    value_loss           | 51.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 12          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.02302653  |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | -0.000615   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.01        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0206     |
# |    reward               | -0.18943828 |
# |    std                  | 1.02        |
# |    value_loss           | 16          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 13          |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.029740829 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | -0.0267     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.8        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.02       |
# |    reward               | 0.9335456   |
# |    std                  | 1.02        |
# |    value_loss           | 33.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 14          |
# |    time_elapsed         | 371         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.012232066 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.0085      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 40.5        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0126     |
# |    reward               | -0.876683   |
# |    std                  | 1.02        |
# |    value_loss           | 71.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 15         |
# |    time_elapsed         | 400        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.02124675 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.8      |
# |    explained_variance   | 0.00546    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 13.3       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0153    |
# |    reward               | 6.001286   |
# |    std                  | 1.02       |
# |    value_loss           | 28.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 16          |
# |    time_elapsed         | 426         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.01638916  |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | 0.00278     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 48.6        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.017      |
# |    reward               | -0.65544564 |
# |    std                  | 1.03        |
# |    value_loss           | 45.8        |
# -----------------------------------------
# day: 2892, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 3266775.84
# total_reward: 2266775.84
# total_cost: 308466.76
# total_trades: 78361
# Sharpe: 0.686
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 17          |
# |    time_elapsed         | 451         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.015969347 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | 0.00614     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22.3        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0123     |
# |    reward               | 0.84648436  |
# |    std                  | 1.03        |
# |    value_loss           | 67.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 18           |
# |    time_elapsed         | 477          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.018810747  |
# |    clip_fraction        | 0.207        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42          |
# |    explained_variance   | 0.00302      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 17.3         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0177      |
# |    reward               | -0.019048598 |
# |    std                  | 1.03         |
# |    value_loss           | 57.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 19          |
# |    time_elapsed         | 503         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.017547948 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.00354     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.31        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0198     |
# |    reward               | -0.7644834  |
# |    std                  | 1.03        |
# |    value_loss           | 15.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 20          |
# |    time_elapsed         | 535         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.029420622 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.00926     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.8        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0148     |
# |    reward               | -0.4488593  |
# |    std                  | 1.03        |
# |    value_loss           | 58.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 21          |
# |    time_elapsed         | 561         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.023054115 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | -1.85e-05   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 28.4        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0157     |
# |    reward               | -9.784605   |
# |    std                  | 1.04        |
# |    value_loss           | 67.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 22          |
# |    time_elapsed         | 588         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.024371462 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | 0.00959     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.12        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.018      |
# |    reward               | 2.0584357   |
# |    std                  | 1.04        |
# |    value_loss           | 26.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 23           |
# |    time_elapsed         | 614          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.026191486  |
# |    clip_fraction        | 0.26         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.2        |
# |    explained_variance   | -0.0205      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 28           |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.014       |
# |    reward               | -0.031134883 |
# |    std                  | 1.04         |
# |    value_loss           | 49.9         |
# ------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 76        |
# |    iterations           | 24        |
# |    time_elapsed         | 641       |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0302732 |
# |    clip_fraction        | 0.283     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -42.3     |
# |    explained_variance   | 0.00686   |
# |    learning_rate        | 0.00025   |
# |    loss                 | 37.7      |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -0.0175   |
# |    reward               | 6.242772  |
# |    std                  | 1.04      |
# |    value_loss           | 66.6      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 25          |
# |    time_elapsed         | 668         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.023661388 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.3       |
# |    explained_variance   | -0.00739    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 52.9        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0136     |
# |    reward               | -1.4111453  |
# |    std                  | 1.04        |
# |    value_loss           | 97.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 26          |
# |    time_elapsed         | 698         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.023850791 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | 0.0112      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.94        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0173     |
# |    reward               | 0.58128256  |
# |    std                  | 1.04        |
# |    value_loss           | 14.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 27          |
# |    time_elapsed         | 723         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.021303374 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | 0.00956     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 20          |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0172     |
# |    reward               | -0.5284958  |
# |    std                  | 1.04        |
# |    value_loss           | 28.1        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 28         |
# |    time_elapsed         | 749        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.03314496 |
# |    clip_fraction        | 0.303      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.4      |
# |    explained_variance   | -0.000477  |
# |    learning_rate        | 0.00025    |
# |    loss                 | 24.1       |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0111    |
# |    reward               | -1.21482   |
# |    std                  | 1.05       |
# |    value_loss           | 46         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 29          |
# |    time_elapsed         | 776         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.014002988 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | 0.085       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.65        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0141     |
# |    reward               | -0.23789747 |
# |    std                  | 1.05        |
# |    value_loss           | 16.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 30          |
# |    time_elapsed         | 802         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.032563508 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.5       |
# |    explained_variance   | 0.0278      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.41        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0183     |
# |    reward               | 0.82560116  |
# |    std                  | 1.05        |
# |    value_loss           | 27.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 31          |
# |    time_elapsed         | 831         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.020317059 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.5       |
# |    explained_variance   | 0.0138      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 34.9        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0144     |
# |    reward               | 0.013675352 |
# |    std                  | 1.05        |
# |    value_loss           | 51.5        |
# -----------------------------------------
# day: 2892, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 2882452.11
# total_reward: 1882452.11
# total_cost: 288896.56
# total_trades: 76878
# Sharpe: 0.620
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 32          |
# |    time_elapsed         | 858         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.017139468 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.5       |
# |    explained_variance   | -0.000715   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.1        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.013      |
# |    reward               | -0.04545553 |
# |    std                  | 1.05        |
# |    value_loss           | 25.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 33          |
# |    time_elapsed         | 884         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.018180598 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.5       |
# |    explained_variance   | 0.0762      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 20.9        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0145     |
# |    reward               | -1.1436034  |
# |    std                  | 1.05        |
# |    value_loss           | 30.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 34          |
# |    time_elapsed         | 911         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.018582206 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.6       |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10          |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0211     |
# |    reward               | 1.1146035   |
# |    std                  | 1.05        |
# |    value_loss           | 31.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 35          |
# |    time_elapsed         | 937         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.019573122 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.6       |
# |    explained_variance   | 0.0165      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 17.1        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0144     |
# |    reward               | -0.9306656  |
# |    std                  | 1.05        |
# |    value_loss           | 37.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 36          |
# |    time_elapsed         | 969         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.020832647 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.6       |
# |    explained_variance   | 0.0683      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.36        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0137     |
# |    reward               | -2.8529122  |
# |    std                  | 1.05        |
# |    value_loss           | 15.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 37           |
# |    time_elapsed         | 995          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.01848427   |
# |    clip_fraction        | 0.174        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.6        |
# |    explained_variance   | 0.0172       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 18.3         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.02        |
# |    reward               | -0.026227772 |
# |    std                  | 1.05         |
# |    value_loss           | 39.1         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 38         |
# |    time_elapsed         | 1020       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.02791179 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.7      |
# |    explained_variance   | 0.12       |
# |    learning_rate        | 0.00025    |
# |    loss                 | 10.4       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00952   |
# |    reward               | -6.7569284 |
# |    std                  | 1.05       |
# |    value_loss           | 39         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 39          |
# |    time_elapsed         | 1046        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.019069001 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.7       |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 20.7        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0186     |
# |    reward               | -1.6437998  |
# |    std                  | 1.06        |
# |    value_loss           | 29.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 40          |
# |    time_elapsed         | 1071        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.015246888 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.7       |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.55        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0129     |
# |    reward               | -1.5915062  |
# |    std                  | 1.06        |
# |    value_loss           | 37.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 41         |
# |    time_elapsed         | 1101       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.02394399 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.8      |
# |    explained_variance   | 0.17       |
# |    learning_rate        | 0.00025    |
# |    loss                 | 20.3       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0118    |
# |    reward               | 0.2877476  |
# |    std                  | 1.06       |
# |    value_loss           | 28.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 42          |
# |    time_elapsed         | 1127        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.013907488 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.9       |
# |    explained_variance   | 0.0687      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 18.9        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0137     |
# |    reward               | 0.35569102  |
# |    std                  | 1.06        |
# |    value_loss           | 34.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 43          |
# |    time_elapsed         | 1153        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.020324975 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.9       |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.86        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0156     |
# |    reward               | 0.85603493  |
# |    std                  | 1.06        |
# |    value_loss           | 16.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 44          |
# |    time_elapsed         | 1180        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.030136464 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43         |
# |    explained_variance   | 0.246       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.18        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0113     |
# |    reward               | 0.26850063  |
# |    std                  | 1.06        |
# |    value_loss           | 33.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 45         |
# |    time_elapsed         | 1206       |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.05434353 |
# |    clip_fraction        | 0.334      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43        |
# |    explained_variance   | 0.107      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 19.6       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.00118    |
# |    reward               | -1.5265553 |
# |    std                  | 1.07       |
# |    value_loss           | 42.5       |
# ----------------------------------------
# day: 2892, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1664886.52
# total_reward: 664886.52
# total_cost: 183096.68
# total_trades: 67888
# Sharpe: 0.325
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 46          |
# |    time_elapsed         | 1237        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.014989346 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43         |
# |    explained_variance   | 0.085       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.94        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00544    |
# |    reward               | -3.038174   |
# |    std                  | 1.07        |
# |    value_loss           | 21.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 47          |
# |    time_elapsed         | 1263        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.022185234 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.1       |
# |    explained_variance   | 0.328       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.7        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0132     |
# |    reward               | 1.4047484   |
# |    std                  | 1.07        |
# |    value_loss           | 21.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 48          |
# |    time_elapsed         | 1289        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.020614486 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.1       |
# |    explained_variance   | 0.133       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 20          |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0135     |
# |    reward               | 5.9025707   |
# |    std                  | 1.07        |
# |    value_loss           | 36.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 49          |
# |    time_elapsed         | 1315        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.04299581  |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.1       |
# |    explained_variance   | -0.00247    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 24.6        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.000694    |
# |    reward               | -0.31254518 |
# |    std                  | 1.07        |
# |    value_loss           | 59.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 50         |
# |    time_elapsed         | 1340       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.03862487 |
# |    clip_fraction        | 0.379      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.2      |
# |    explained_variance   | -0.00972   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 8.94       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.00408   |
# |    reward               | -0.2987247 |
# |    std                  | 1.07       |
# |    value_loss           | 22.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 51         |
# |    time_elapsed         | 1370       |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.04020236 |
# |    clip_fraction        | 0.354      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.3      |
# |    explained_variance   | -0.000739  |
# |    learning_rate        | 0.00025    |
# |    loss                 | 46.1       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0104    |
# |    reward               | 0.2990325  |
# |    std                  | 1.08       |
# |    value_loss           | 95.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 52         |
# |    time_elapsed         | 1397       |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.04216921 |
# |    clip_fraction        | 0.323      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.4      |
# |    explained_variance   | 0.054      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 65.2       |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.00123   |
# |    reward               | -5.154238  |
# |    std                  | 1.08       |
# |    value_loss           | 85.6       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 53          |
# |    time_elapsed         | 1423        |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.025871847 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.4       |
# |    explained_variance   | 0.166       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.27        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00949    |
# |    reward               | -0.318554   |
# |    std                  | 1.08        |
# |    value_loss           | 23          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 54         |
# |    time_elapsed         | 1449       |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.02132745 |
# |    clip_fraction        | 0.178      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.5      |
# |    explained_variance   | 0.11       |
# |    learning_rate        | 0.00025    |
# |    loss                 | 19.7       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.0122    |
# |    reward               | 0.8594486  |
# |    std                  | 1.08       |
# |    value_loss           | 67.6       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 55          |
# |    time_elapsed         | 1475        |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.037293322 |
# |    clip_fraction        | 0.356       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.5       |
# |    explained_variance   | 0.113       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 30.3        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00278    |
# |    reward               | 2.8094454   |
# |    std                  | 1.09        |
# |    value_loss           | 102         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 56          |
# |    time_elapsed         | 1506        |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.031794734 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.6       |
# |    explained_variance   | 0.0784      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.4        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0132     |
# |    reward               | 3.627858    |
# |    std                  | 1.09        |
# |    value_loss           | 27.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 57          |
# |    time_elapsed         | 1532        |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.024694826 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.6       |
# |    explained_variance   | 0.105       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.9        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0148     |
# |    reward               | 0.08760023  |
# |    std                  | 1.09        |
# |    value_loss           | 33.8        |
# ...
# |    iterations           | 80         |
# |    time_elapsed         | 2147       |
# |    total_timesteps      | 163840     |
# | train/                  |            |
# |    approx_kl            | 0.04107189 |
# |    clip_fraction        | 0.389      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -44.6      |
# |    explained_variance   | 0.152      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 24.6       |
# |    n_updates            | 790        |
# |    policy_gradient_loss | 0.000164   |
# |    reward               | 0.64054996 |
# |    std                  | 1.13       |
# |    value_loss           | 61.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 81          |
# |    time_elapsed         | 2173        |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.025811853 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.7       |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 25.6        |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0121     |
# |    reward               | -0.18078189 |
# |    std                  | 1.13        |
# |    value_loss           | 119         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 82          |
# |    time_elapsed         | 2205        |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.024248166 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.7       |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 47.3        |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.0127     |
# |    reward               | -0.5142531  |
# |    std                  | 1.13        |
# |    value_loss           | 140         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 83          |
# |    time_elapsed         | 2231        |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.0222171   |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.8       |
# |    explained_variance   | 0.0984      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 53          |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00323    |
# |    reward               | -0.41894272 |
# |    std                  | 1.14        |
# |    value_loss           | 113         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 84         |
# |    time_elapsed         | 2257       |
# |    total_timesteps      | 172032     |
# | train/                  |            |
# |    approx_kl            | 0.03587889 |
# |    clip_fraction        | 0.309      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -44.8      |
# |    explained_variance   | 0.192      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 15.4       |
# |    n_updates            | 830        |
# |    policy_gradient_loss | 0.00167    |
# |    reward               | -1.2265228 |
# |    std                  | 1.14       |
# |    value_loss           | 31.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 85          |
# |    time_elapsed         | 2282        |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.037989747 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.8       |
# |    explained_variance   | 0.1         |
# |    learning_rate        | 0.00025     |
# |    loss                 | 28.4        |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0055     |
# |    reward               | 0.16165245  |
# |    std                  | 1.14        |
# |    value_loss           | 90.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 86          |
# |    time_elapsed         | 2308        |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.030908441 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.9       |
# |    explained_variance   | 0.0911      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 37          |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.00306    |
# |    reward               | -0.40664142 |
# |    std                  | 1.14        |
# |    value_loss           | 67.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 87          |
# |    time_elapsed         | 2338        |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.024046257 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.9       |
# |    explained_variance   | 0.248       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.64        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.00657    |
# |    reward               | 3.035591    |
# |    std                  | 1.14        |
# |    value_loss           | 27.8        |
# -----------------------------------------
# day: 2892, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 5267932.34
# total_reward: 4267932.34
# total_cost: 277131.32
# total_trades: 74620
# Sharpe: 0.883
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 88          |
# |    time_elapsed         | 2363        |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.029371753 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.9       |
# |    explained_variance   | 0.164       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 31.7        |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.00658    |
# |    reward               | -2.256181   |
# |    std                  | 1.14        |
# |    value_loss           | 74          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 89          |
# |    time_elapsed         | 2388        |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.034195937 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.9       |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 65.2        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.00351    |
# |    reward               | -0.09514571 |
# |    std                  | 1.14        |
# |    value_loss           | 90.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 90         |
# |    time_elapsed         | 2413       |
# |    total_timesteps      | 184320     |
# | train/                  |            |
# |    approx_kl            | 0.05222631 |
# |    clip_fraction        | 0.361      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -45        |
# |    explained_variance   | 0.0052     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 48.9       |
# |    n_updates            | 890        |
# |    policy_gradient_loss | 0.00259    |
# |    reward               | -1.3102162 |
# |    std                  | 1.15       |
# |    value_loss           | 106        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 91          |
# |    time_elapsed         | 2438        |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.021441638 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.1       |
# |    explained_variance   | 0.271       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.82        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00185    |
# |    reward               | -1.2569844  |
# |    std                  | 1.15        |
# |    value_loss           | 20.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 92          |
# |    time_elapsed         | 2467        |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.020183245 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.1       |
# |    explained_variance   | 0.111       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 26.5        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.00629    |
# |    reward               | -1.3760247  |
# |    std                  | 1.15        |
# |    value_loss           | 95.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 93          |
# |    time_elapsed         | 2492        |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.033915754 |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.1       |
# |    explained_variance   | 0.105       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 57.3        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | 0.00467     |
# |    reward               | -1.9479201  |
# |    std                  | 1.15        |
# |    value_loss           | 104         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 94          |
# |    time_elapsed         | 2517        |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.021955255 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.2       |
# |    explained_variance   | 0.075       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.5        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.00862    |
# |    reward               | 0.29823583  |
# |    std                  | 1.15        |
# |    value_loss           | 29.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 95          |
# |    time_elapsed         | 2542        |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.028761476 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.2       |
# |    explained_variance   | 0.051       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 41.3        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00655    |
# |    reward               | -0.61774546 |
# |    std                  | 1.15        |
# |    value_loss           | 67.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 96          |
# |    time_elapsed         | 2568        |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.011284558 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.2       |
# |    explained_variance   | 0.0148      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22.3        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0088     |
# |    reward               | 2.136878    |
# |    std                  | 1.15        |
# |    value_loss           | 90.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 97          |
# |    time_elapsed         | 2601        |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.020546358 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.3       |
# |    explained_variance   | 0.112       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.5        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0055     |
# |    reward               | 1.7426864   |
# |    std                  | 1.15        |
# |    value_loss           | 36          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 98          |
# |    time_elapsed         | 2627        |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.019327708 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.3       |
# |    explained_variance   | 0.0804      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 32.3        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0103     |
# |    reward               | -0.297001   |
# |    std                  | 1.16        |
# |    value_loss           | 59.9        |
# -----------------------------------------

# %%
trained_ppo.save(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None

# %% [markdown]
# Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100,
              "buffer_size": 1000000,
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to results/td3

# %%
trained_td3 = agent.train_model(model=model_td3,
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None
# Out:
# day: 2892, episode: 110
# begin_total_asset: 1000000.00
# end_total_asset: 5059044.67
# total_reward: 4059044.67
# total_cost: 999.00
# total_trades: 57840
# Sharpe: 0.838
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 28       |
# |    time_elapsed    | 401      |
# |    total_timesteps | 11572    |
# | train/             |          |
# |    actor_loss      | 76.8     |
# |    critic_loss     | 1.36e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8679     |
# |    reward          | 4.711856 |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 25       |
# |    time_elapsed    | 920      |
# |    total_timesteps | 23144    |
# | train/             |          |
# |    actor_loss      | 38.1     |
# |    critic_loss     | 246      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 20251    |
# |    reward          | 4.711856 |
# ---------------------------------
# day: 2892, episode: 120
# begin_total_asset: 1000000.00
# end_total_asset: 5059044.67
# total_reward: 4059044.67
# total_cost: 999.00
# total_trades: 57840
# Sharpe: 0.838
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 24       |
# |    time_elapsed    | 1441     |
# |    total_timesteps | 34716    |
# | train/             |          |
# |    actor_loss      | 29.6     |
# |    critic_loss     | 35.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31823    |
# |    reward          | 4.711856 |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 23       |
# |    time_elapsed    | 1958     |
# |    total_timesteps | 46288    |
# | train/             |          |
# |    actor_loss      | 28.6     |
# |    critic_loss     | 17.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43395    |
# |    reward          | 4.711856 |
# ---------------------------------

# %%
trained_td3.save(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None

# %% [markdown]
# Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to results/sac

# %%
trained_sac = agent.train_model(model=model_sac,
                             tb_log_name='sac',
                             total_timesteps=10000) if if_using_sac else None
# Out:
# day: 2892, episode: 140
# begin_total_asset: 1000000.00
# end_total_asset: 6803386.09
# total_reward: 5803386.09
# total_cost: 11483.98
# total_trades: 52531
# Sharpe: 1.004
# =================================

# %%
trained_sac.save(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# BACKTESTING

# %%
train = pd.read_csv('train_data.csv')
trade = pd.read_csv('trade_data.csv')

# If you are not using the data generated from part 1 of this tutorial, make sure
# it has the columns and index in the form that could be make into the environment.
# Then you can comment and skip the following lines.
train = train.set_index(train.columns[0])
train.index.names = ['']
trade = trade.set_index(trade.columns[0])
trade.index.names = ['']

# %%
if_using_a2c = True
if_using_ddpg = True
if_using_ppo = True
if_using_td3 = True
if_using_sac = True

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from stable_baselines3 import A2C, DDPG, PPO, SAC, TD3

from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.config import INDICATORS, TRAINED_MODEL_DIR
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader

# %matplotlib inline

# %%
trained_a2c = A2C.load(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None
trained_ddpg = DDPG.load(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None
trained_ppo = PPO.load(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None
trained_td3 = TD3.load(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None
trained_sac = SAC.load(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %%
stock_dimension = len(trade.tic.unique())
state_space = 1 + 2 * stock_dimension + len(INDICATORS) * stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_a2c,
    environment = e_trade_gym) if if_using_a2c else (None, None)
# Out:
# hit end!

# %%
df_account_value_ddpg, df_actions_ddpg = DRLAgent.DRL_prediction(
    model=trained_ddpg,
    environment = e_trade_gym) if if_using_ddpg else (None, None)
# Out:
# hit end!

# %%
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_ppo,
    environment = e_trade_gym) if if_using_ppo else (None, None)
# Out:
# hit end!

# %%
df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
    model=trained_td3,
    environment = e_trade_gym) if if_using_td3 else (None, None)
# Out:
# hit end!

# %%
df_account_value_sac, df_actions_sac = DRLAgent.DRL_prediction(
    model=trained_sac,
    environment = e_trade_gym) if if_using_sac else (None, None)
# Out:
# hit end!

# %%
def process_df_for_mvo(df):
  return df.pivot(index="date", columns="tic", values="close")

# %%
# Codes in this section partially refer to Dr G A Vijayalakshmi Pai

# https://www.kaggle.com/code/vijipai/lesson-5-mean-variance-optimization-of-portfolios/notebook

def StockReturnsComputing(StockPrice, Rows, Columns):
  import numpy as np
  StockReturn = np.zeros([Rows-1, Columns])
  for j in range(Columns):        # j: Assets
    for i in range(Rows-1):     # i: Daily Prices
      StockReturn[i,j]=((StockPrice[i+1, j]-StockPrice[i,j])/StockPrice[i,j])* 100

  return StockReturn

# %%
StockData = process_df_for_mvo(train)
TradeData = process_df_for_mvo(trade)

TradeData.to_numpy()
# Out:
# array([[ 89.13300323, 228.75476074,  90.06214905, ...,  45.19827652,
#          34.30270386, 113.78935242],
#        [ 89.13300323, 231.55230713,  90.33028412, ...,  45.29749298,
#          35.2257309 , 113.33300781],
#        [ 91.51733398, 229.76797485,  92.48487854, ...,  45.66952515,
#          36.2158699 , 113.02877808],
#        ...,
#        [146.7467041 , 192.91072083, 177.35269165, ...,  46.44017792,
#          43.46643448, 145.47285461],
#        [147.41802979, 193.88623047, 176.02964783, ...,  46.88179398,
#          42.66281128, 144.20289612],
#        [146.95402527, 191.93513489, 173.18907166, ...,  46.48434448,
#          41.61191177, 143.02018738]])

# %%
#compute asset returns
arStockPrices = np.asarray(StockData)
[Rows, Cols]=arStockPrices.shape
arReturns = StockReturnsComputing(arStockPrices, Rows, Cols)

#compute mean returns and variance covariance matrix of returns
meanReturns = np.mean(arReturns, axis = 0)
covReturns = np.cov(arReturns, rowvar=False)

#set precision for printing results
np.set_printoptions(precision=3, suppress = True)

#display mean returns and variance-covariance matrix of returns
print('Mean returns of assets in k-portfolio 1\n', meanReturns)
print('Variance-Covariance matrix of returns\n', covReturns)
# Out:
# Mean returns of assets in k-portfolio 1
#  [0.136 0.068 0.086 0.083 0.066 0.134 0.06  0.035 0.072 0.056 0.103 0.073
#  0.033 0.076 0.047 0.073 0.042 0.056 0.054 0.056 0.103 0.089 0.041 0.053
#  0.104 0.11  0.044 0.042 0.042]
# Variance-Covariance matrix of returns
#  [[3.156 1.066 1.768 1.669 1.722 1.814 1.569 1.302 1.302 1.811 1.303 1.432
#   1.218 1.674 0.74  1.839 0.719 0.884 1.241 0.823 1.561 1.324 0.752 1.027
#   1.298 1.466 0.657 1.078 0.631]
#  [1.066 2.571 1.306 1.123 1.193 1.319 1.116 1.053 1.045 1.269 1.068 1.089
#   0.899 1.218 0.926 1.391 0.682 0.727 1.025 1.156 1.166 0.984 0.798 0.956
#   1.259 1.111 0.688 1.091 0.682]
#  [1.768 1.306 4.847 2.73  2.6   2.128 1.944 2.141 2.17  3.142 1.932 2.283
#   1.56  2.012 0.993 3.707 1.094 1.319 1.845 1.236 1.899 1.894 1.041 1.921
#   1.823 2.314 0.986 1.421 0.707]
#  [1.669 1.123 2.73  4.892 2.363 1.979 1.7   2.115 1.959 2.387 1.773 2.319
#   1.571 1.797 0.968 2.597 1.144 1.298 1.643 1.071 1.615 1.775 0.91  1.666
#   1.707 1.784 0.82  1.345 0.647]
#  [1.722 1.193 2.6   2.363 4.019 2.127 1.917 2.059 1.817 2.46  1.577 2.238
#   1.513 1.929 0.925 2.64  0.947 0.971 1.894 1.089 1.711 1.642 0.865 1.456
#   1.478 1.687 0.92  1.326 0.697]
#  [1.814 1.319 2.128 1.979 2.127 5.384 1.974 1.549 1.683 2.122 1.624 1.771
#   1.441 1.939 0.846 2.191 0.837 1.075 1.475 1.041 1.978 1.768 0.784 1.328
#   1.365 1.912 0.787 1.28  0.666]
#  [1.569 1.116 1.944 1.7   1.917 1.974 3.081 1.483 1.534 1.937 1.367 1.62
#   1.399 1.843 0.894 2.057 0.794 0.905 1.438 1.014 1.72  1.382 0.865 1.206
#   1.273 1.488 0.811 1.173 0.753]
#  [1.302 1.053 2.141 2.115 2.059 1.549 1.483 2.842 1.525 2.044 1.428 1.783
#   1.308 1.533 0.878 2.279 0.938 1.092 1.385 1.078 1.429 1.314 0.831 1.459
#   1.466 1.48  0.83  1.042 0.567]
#  [1.302 1.045 2.17  1.959 1.817 1.683 1.534 1.525 2.661 1.987 1.454 1.748
#   1.217 1.475 0.791 2.216 0.896 0.973 1.396 0.949 1.379 1.407 0.859 1.268
#   1.281 1.454 0.81  1.143 0.667]
#  [1.811 1.269 3.142 2.387 2.46  2.122 1.937 2.044 1.987 4.407 1.789 2.12
#   1.593 1.982 0.945 3.96  0.956 1.094 1.758 1.157 1.788 1.692 0.905 1.879
#   1.712 2.    0.945 1.421 0.713]
#  [1.303 1.068 1.932 1.773 1.577 1.624 1.367 1.428 1.454 1.789 2.373 1.51
#   1.166 1.501 0.756 1.941 0.824 0.998 1.239 0.887 1.366 1.414 0.797 1.299
#   1.296 1.41  0.764 1.071 0.783]
#  [1.432 1.089 2.283 2.319 2.238 1.771 1.62  1.783 1.748 2.12  1.51  2.516
#   1.326 1.575 0.889 2.345 0.958 1.022 1.623 1.02  1.489 1.532 0.848 1.377
#   1.444 1.547 0.81  1.211 0.63 ]
#  [1.218 0.899 1.56  1.571 1.513 1.441 1.399 1.308 1.217 1.593 1.166 1.326
#   2.052 1.399 0.727 1.749 0.786 0.795 1.154 0.829 1.296 1.12  0.743 1.105
#   1.088 1.214 0.739 0.998 0.598]
#  [1.674 1.218 2.012 1.797 1.929 1.939 1.843 1.533 1.475 1.982 1.501 1.575
#   1.399 3.289 0.853 2.112 0.85  0.89  1.412 1.002 1.9   1.352 0.842 1.317
#   1.334 1.487 0.847 1.165 0.766]
#  [0.74  0.926 0.993 0.968 0.925 0.846 0.894 0.878 0.791 0.945 0.756 0.889
#   0.727 0.853 1.153 1.027 0.642 0.59  0.848 0.892 0.825 0.748 0.694 0.761
#   0.929 0.819 0.61  0.806 0.547]
#  [1.839 1.391 3.707 2.597 2.64  2.191 2.057 2.279 2.216 3.96  1.941 2.345
#   1.749 2.112 1.027 5.271 1.08  1.235 1.892 1.297 1.91  1.85  1.068 2.164
#   1.85  2.169 1.112 1.555 0.779]
#  [0.719 0.682 1.094 1.144 0.947 0.837 0.794 0.938 0.896 0.956 0.824 0.958
#   0.786 0.85  0.642 1.08  1.264 0.679 0.804 0.74  0.819 0.845 0.749 0.891
#   0.849 0.794 0.633 0.719 0.514]
#  [0.884 0.727 1.319 1.298 0.971 1.075 0.905 1.092 0.973 1.094 0.998 1.022
#   0.795 0.89  0.59  1.235 0.679 1.518 0.816 0.719 0.943 1.027 0.615 1.
#   0.947 0.994 0.533 0.673 0.504]
#  [1.241 1.025 1.845 1.643 1.894 1.475 1.438 1.385 1.396 1.758 1.239 1.623
#   1.154 1.412 0.848 1.892 0.804 0.816 2.028 0.9   1.265 1.243 0.787 1.194
#   1.193 1.282 0.752 1.099 0.622]
#  [0.823 1.156 1.236 1.071 1.089 1.041 1.014 1.078 0.949 1.157 0.887 1.02
#   0.829 1.002 0.892 1.297 0.74  0.719 0.9   2.007 0.952 0.849 0.732 1.008
#   1.15  0.933 0.722 0.897 0.614]
#  [1.561 1.166 1.899 1.615 1.711 1.978 1.72  1.429 1.379 1.788 1.366 1.489
#   1.296 1.9   0.825 1.91  0.819 0.943 1.265 0.952 2.759 1.308 0.832 1.214
#   1.285 1.493 0.793 1.113 0.705]
#  [1.324 0.984 1.894 1.775 1.642 1.768 1.382 1.314 1.407 1.692 1.414 1.532
#   1.12  1.352 0.748 1.85  0.845 1.027 1.243 0.849 1.308 2.864 0.751 1.153
#   1.26  1.411 0.71  1.046 0.651]
#  [0.752 0.798 1.041 0.91  0.865 0.784 0.865 0.831 0.859 0.905 0.797 0.848
#   0.743 0.842 0.694 1.068 0.749 0.615 0.787 0.732 0.832 0.751 1.289 0.806
#   0.766 0.763 0.663 0.797 0.645]
#  [1.027 0.956 1.921 1.666 1.456 1.328 1.206 1.459 1.268 1.879 1.299 1.377
#   1.105 1.317 0.761 2.164 0.891 1.    1.194 1.008 1.214 1.153 0.806 2.27
#   1.259 1.294 0.812 0.986 0.676]
#  [1.298 1.259 1.823 1.707 1.478 1.365 1.273 1.466 1.281 1.712 1.296 1.444
#   1.088 1.334 0.929 1.85  0.849 0.947 1.193 1.15  1.285 1.26  0.766 1.259
#   3.352 1.267 0.697 1.137 0.685]
#  [1.466 1.111 2.314 1.784 1.687 1.912 1.488 1.48  1.454 2.    1.41  1.547
#   1.214 1.487 0.819 2.169 0.794 0.994 1.282 0.933 1.493 1.411 0.763 1.294
#   1.267 2.982 0.709 1.007 0.656]
#  [0.657 0.688 0.986 0.82  0.92  0.787 0.811 0.83  0.81  0.945 0.764 0.81
#   0.739 0.847 0.61  1.112 0.633 0.533 0.752 0.722 0.793 0.71  0.663 0.812
#   0.697 0.709 1.371 0.697 0.561]
#  [1.078 1.091 1.421 1.345 1.326 1.28  1.173 1.042 1.143 1.421 1.071 1.211
#   0.998 1.165 0.806 1.555 0.719 0.673 1.099 0.897 1.113 1.046 0.797 0.986
#   1.137 1.007 0.697 3.073 0.759]
#  [0.631 0.682 0.707 0.647 0.697 0.666 0.753 0.567 0.667 0.713 0.783 0.63
#   0.598 0.766 0.547 0.779 0.514 0.504 0.622 0.614 0.705 0.651 0.645 0.676
#   0.685 0.656 0.561 0.759 1.452]]

# %%
from pypfopt.efficient_frontier import EfficientFrontier

ef_mean = EfficientFrontier(meanReturns, covReturns, weight_bounds=(0, 0.5))
raw_weights_mean = ef_mean.max_sharpe()
cleaned_weights_mean = ef_mean.clean_weights()
mvo_weights = np.array([1000000 * cleaned_weights_mean[i] for i in range(len(cleaned_weights_mean))])
mvo_weights
# Out:
# array([424250.,      0.,      0.,      0.,      0., 108650.,      0.,
#             0.,      0.,      0., 181450.,      0.,      0.,      0.,
#             0.,      0.,      0.,      0.,      0.,      0.,  16960.,
#             0.,      0.,      0., 133540., 135150.,      0.,      0.,
#             0.])

# %%
LastPrice = np.array([1/p for p in StockData.tail(1).to_numpy()[0]])
Initial_Portfolio = np.multiply(mvo_weights, LastPrice)
Initial_Portfolio
# Out:
# array([4750.738,    0.   ,    0.   ,    0.   ,    0.   ,  579.993,
#           0.   ,    0.   ,    0.   ,    0.   ,  782.279,    0.   ,
#           0.   ,    0.   ,    0.   ,    0.   ,    0.   ,    0.   ,
#           0.   ,    0.   ,   86.007,    0.   ,    0.   ,    0.   ,
#         474.034,  717.057,    0.   ,    0.   ,    0.   ])

# %%
Portfolio_Assets = TradeData @ Initial_Portfolio
MVO_result = pd.DataFrame(Portfolio_Assets, columns=["Mean Var"])
MVO_result
# Out:
#                 Mean Var
# date
# 2020-07-01  1.001917e+06
# 2020-07-02  1.004235e+06
# 2020-07-06  1.023225e+06
# 2020-07-07  1.014021e+06
# 2020-07-08  1.029461e+06
# ...                  ...
# 2021-10-21  1.533022e+06
# 2021-10-22  1.535667e+06
# 2021-10-25  1.542078e+06
# 2021-10-26  1.545514e+06
# 2021-10-27  1.534916e+06
#
# [335 rows x 1 columns]

# %%
TRAIN_START_DATE = '2009-01-01'
TRAIN_END_DATE = '2020-07-01'
TRADE_START_DATE = '2020-07-01'
TRADE_END_DATE = '2021-10-29'

# %%
df_dji = YahooDownloader(
    start_date=TRADE_START_DATE, end_date=TRADE_END_DATE, ticker_list=["dji"]
).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (319, 8)

# %%
df_dji = df_dji[["date", "close"]]
fst_day = df_dji["close"][0]
dji = pd.merge(
    df_dji["date"],
    df_dji["close"].div(fst_day).mul(1000000),
    how="outer",
    left_index=True,
    right_index=True,
).set_index("date")

# %% [markdown]
# **Backtesting** **Results**

# %%
df_result_a2c = (
    df_account_value_a2c.set_index(df_account_value_a2c.columns[0])
    if if_using_a2c
    else None
)
df_result_ddpg = (
    df_account_value_ddpg.set_index(df_account_value_ddpg.columns[0])
    if if_using_ddpg
    else None
)
df_result_ppo = (
    df_account_value_ppo.set_index(df_account_value_ppo.columns[0])
    if if_using_ppo
    else None
)
df_result_td3 = (
    df_account_value_td3.set_index(df_account_value_td3.columns[0])
    if if_using_td3
    else None
)
df_result_sac = (
    df_account_value_sac.set_index(df_account_value_sac.columns[0])
    if if_using_sac
    else None
)

result = pd.DataFrame(
    {
        "a2c": df_result_a2c["account_value"] if if_using_a2c else None,
        "ddpg": df_result_ddpg["account_value"] if if_using_ddpg else None,
        "ppo": df_result_ppo["account_value"] if if_using_ppo else None,
        "td3": df_result_td3["account_value"] if if_using_td3 else None,
        "sac": df_result_sac["account_value"] if if_using_sac else None,
        "mvo": MVO_result["Mean Var"],
        "dji": dji["close"],
    }
)

# %%
result
# Out:
#                      a2c          ddpg           ppo           td3  \
# date
# 2020-07-01  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# 2020-07-02  1.000443e+06  1.000589e+06  1.000105e+06  1.000916e+06
# 2020-07-06  1.002918e+06  1.007055e+06  1.002052e+06  1.009203e+06
# 2020-07-07  9.983929e+05  9.960112e+05  9.997191e+05  9.979227e+05
# 2020-07-08  1.001027e+06  9.997024e+05  1.001476e+06  1.005262e+06
# ...                  ...           ...           ...           ...
# 2021-10-22  1.335268e+06  1.345957e+06  1.518233e+06  1.394588e+06
# 2021-10-25  1.339244e+06  1.341077e+06  1.515770e+06  1.397858e+06
# 2021-10-26  1.339783e+06  1.344742e+06  1.517948e+06  1.400138e+06
# 2021-10-27  1.321964e+06  1.330675e+06  1.522545e+06  1.392975e+06
# 2021-10-28           NaN           NaN           NaN           NaN
#
#                      sac           mvo           dji
# date
# 2020-07-01  1.000000e+06  1.001917e+06  1.000000e+06
# 2020-07-02  1.000392e+06  1.004235e+06           NaN
# 2020-07-06  1.006385e+06  1.023225e+06  1.021449e+06
# 2020-07-07  9.980627e+05  1.014021e+06  1.006031e+06
# 2020-07-08  1.002437e+06  1.029461e+06  1.012912e+06
# ...                  ...           ...           ...
# 2021-10-22  1.477080e+06  1.535667e+06  1.386322e+06
# 2021-10-25  1.481731e+06  1.542078e+06  1.388813e+06
# 2021-10-26  1.480916e+06  1.545514e+06  1.389427e+06
# 2021-10-27  1.480576e+06  1.534916e+06  1.379083e+06
# 2021-10-28           NaN           NaN  1.388401e+06
#
# [336 rows x 7 columns]

# %%
plt.rcParams["figure.figsize"] = (15,5)
plt.figure()
result.plot()
# Out:
# <Axes: xlabel='date'>
